# %%
import numpy as np
import pandas as pd
import pickle
from tqdm import tqdm
import gc, os
import time
from datetime import datetime
import lightgbm as lgb
from sklearn.preprocessing import MinMaxScaler
import warnings
warnings.filterwarnings('ignore')

# %%
trn_user_item_feats_df = pd.read_csv('./FE/final_trn_user_item_feats_df.csv')
trn_user_item_feats_df['click_article_id'] = trn_user_item_feats_df['click_article_id'].astype(int)
tst_user_item_feats_df = pd.read_csv('./FE/final_tst_user_item_feats_df.csv')
tst_user_item_feats_df['click_article_id'] = tst_user_item_feats_df['click_article_id'].astype(int)

del tst_user_item_feats_df['label']

# %%
del trn_user_item_feats_df['Unnamed: 0']
del tst_user_item_feats_df['Unnamed: 0']

# %%
trn_user_item_feats_df_rank_model = trn_user_item_feats_df.copy()
    
tst_user_item_feats_df_rank_model = tst_user_item_feats_df.copy()

# %%
# feature columns
lgb_cols = ['sim0', 'time_diff0', 'word_diff0','sim_max', 'sim_min', 'sim_sum', 
            'sim_mean', 'score','click_size', 'time_diff_mean', 'active_level',
            'click_environment','click_deviceGroup', 'click_os', 'click_country', 
            'click_region','click_referrer_type',
            'words_hbo', 'category_id', 'created_at_ts','words_count']

# %%
trn_user_item_feats_df_rank_model.sort_values(by=['user_id'], inplace=True)
g_train = trn_user_item_feats_df_rank_model.groupby(['user_id'], as_index=False).count()["label"].values

# %%
lgb_ranker = lgb.LGBMRanker(boosting_type='gbdt', num_leaves=31, reg_alpha=0.0, reg_lambda=1,
                            max_depth=-1, n_estimators=100, subsample=0.7, colsample_bytree=0.7, subsample_freq=1,
                            learning_rate=0.01, min_child_weight=50, random_state=2018, n_jobs= 16)

# %%
lgb_ranker.fit(trn_user_item_feats_df[lgb_cols], trn_user_item_feats_df['label'], group=g_train)
# Out:
# LGBMRanker(boosting_type='gbdt', class_weight=None, colsample_bytree=0.7,
#            importance_type='split', learning_rate=0.01, max_depth=-1,
#            min_child_samples=20, min_child_weight=50, min_split_gain=0.0,
#            n_estimators=100, n_jobs=16, num_leaves=31, objective=None,
#            random_state=2018, reg_alpha=0.0, reg_lambda=1, silent=True,
#            subsample=0.7, subsample_for_bin=200000, subsample_freq=1)

# %%
tst_user_item_feats_df['pred_score'] = lgb_ranker.predict(tst_user_item_feats_df[lgb_cols], num_iteration=lgb_ranker.best_iteration_)

# %%
rank_results = tst_user_item_feats_df[['user_id', 'click_article_id', 'pred_score']]

# %%
def submit(recall_df, topk=5, model_name=None):
    recall_df = recall_df.sort_values(by=['user_id', 'pred_score'])
    recall_df['rank'] = recall_df.groupby(['user_id'])['pred_score'].rank(ascending=False, method='first')
    
    # 判断是不是每个用户都有5篇文章及以上
    tmp = recall_df.groupby('user_id').apply(lambda x: x['rank'].max())
    assert tmp.min() >= topk
    
    del recall_df['pred_score']
    submit = recall_df[recall_df['rank'] <= topk].set_index(['user_id', 'rank']).unstack(-1).reset_index()
    
    submit.columns = [int(col) if isinstance(col, int) else col for col in submit.columns.droplevel(0)]
    # 按照提交格式定义列名
    submit = submit.rename(columns={'': 'user_id', 1: 'article_1', 2: 'article_2', 
                                                  3: 'article_3', 4: 'article_4', 5: 'article_5'})
    
    save_name = model_name + '_' + datetime.today().strftime('%m-%d') + '.csv'
    submit.to_csv(save_name, index=False, header=True)

# %%
tst_user_item_feats_df[tst_user_item_feats_df["user_id"]==200001]
# Out:
#          user_id  click_article_id       sim0  time_diff0  word_diff0  \
# 10233     200001            336221  10.237462   638233000          18
# 93366     200001            272143  11.962455    13058000           8
# 116844    200001            234698  10.895900   643669000           7
# 327387    200001            235616  10.165027   661541000          44
# 369092    200001            300473   5.471592    14013000           6
# ...          ...               ...        ...         ...         ...
# 2423470   200001            187067   5.292248    25713000          54
# 2437100   200001             70033   5.824065    43667000          41
# 2438515   200001            236613   4.835308    78904000           2
# 2452083   200001             50864   5.461739    48726000          26
# 2465597   200001             73500   4.480184    48527000           5
#
#            sim_max    sim_min    sim_sum   sim_mean  score  ...  click_os  \
# 10233    10.237462  10.237462  10.237462  10.237462      1  ...         2
# 93366    11.962455  11.962455  11.962455  11.962455      3  ...         2
# 116844   10.895900  10.895900  10.895900  10.895900      1  ...         2
# 327387   10.165027  10.165027  10.165027  10.165027      1  ...         2
# 369092    5.471592   5.471592   5.471592   5.471592      1  ...         2
# ...            ...        ...        ...        ...    ...  ...       ...
# 2423470   5.292248   5.292248   5.292248   5.292248      1  ...         2
# 2437100   5.824065   5.824065   5.824065   5.824065      1  ...         2
# 2438515   4.835308   4.835308   4.835308   4.835308      1  ...         2
# 2452083   5.461739   5.461739   5.461739   5.461739      1  ...         2
# 2465597   4.480184   4.480184   4.480184   4.480184      1  ...         2
#
#          click_country  click_region  click_referrer_type  words_hbo  \
# 10233                1            18                    7      176.0
# 93366                1            18                    7      176.0
# 116844               1            18                    7      176.0
# 327387               1            18                    7      176.0
# 369092               1            18                    7      176.0
# ...                ...           ...                  ...        ...
# 2423470              1            18                    7      176.0
# 2437100              1            18                    7      176.0
# 2438515              1            18                    7      176.0
# 2452083              1            18                    7      176.0
# 2465597              1            18                    7      176.0
#
#          category_id  created_at_ts  words_count  is_cat_hab  pred_score
# 10233            437  1507613161000          158           0   -0.611670
# 93366            399  1506961870000          184           0   -1.019778
# 116844           375  1507618597000          183           0   -0.617775
# 327387           375  1507636469000          220           0   -0.627089
# 369092           428  1506960915000          182           0    0.064181
# ...              ...            ...          ...         ...         ...
# 2423470          302  1506949215000          122           0    0.074599
# 2437100          136  1507018595000          217           0   -0.044256
# 2438515          375  1506896024000          174           0   -0.178915
# 2452083           99  1506926202000          202           0   -0.043501
# 2465597          138  1506926401000          181           0   -0.041673
#
# [123 rows x 26 columns]

# %%
submit(rank_results, topk=5, model_name="lgb_ranker")

# %%
# 模型及参数的定义
lgb_Classfication = lgb.LGBMClassifier(boosting_type='gbdt', num_leaves=31, reg_alpha=0.0, reg_lambda=1,
                            max_depth=-1, n_estimators=500, subsample=0.7, colsample_bytree=0.7, subsample_freq=1,
                            learning_rate=0.01, min_child_weight=50, random_state=2018, n_jobs= 16, verbose=10)

# %%
lgb_Classfication.fit(trn_user_item_feats_df_rank_model[lgb_cols], trn_user_item_feats_df_rank_model['label'])
# Out:
# [LightGBM] [Info] Number of positive: 154872, number of negative: 224410
# [LightGBM] [Debug] Dataset::GetMultiBinFromAllFeatures: sparse rate 0.048712
# [LightGBM] [Debug] init for col-wise cost 0.000446 seconds, init for row-wise cost 0.013703 seconds
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.004404 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Debug] Using Dense Multi-Val Bin
# [LightGBM] [Info] Total Bins 3397
# [LightGBM] [Info] Number of data points in the train set: 379282, number of used features: 21
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.408329 -> initscore=-0.370876
# [LightGBM] [Info] Start training from score -0.370876
# [LightGBM] [Debug] Re-bagging, using 265663 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 8
# [LightGBM] [Debug] Re-bagging, using 265164 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 7
# [LightGBM] [Debug] Re-bagging, using 265552 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 8
# [LightGBM] [Debug] Re-bagging, using 265372 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 7
# [LightGBM] [Debug] Re-bagging, using 265508 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 9
# [LightGBM] [Debug] Re-bagging, using 266102 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 9
# [LightGBM] [Debug] Re-bagging, using 265316 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 9
# [LightGBM] [Debug] Re-bagging, using 266059 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 8
# [LightGBM] [Debug] Re-bagging, using 265639 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 7
# [LightGBM] [Debug] Re-bagging, using 265274 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 8
# [LightGBM] [Debug] Re-bagging, using 265222 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 9
# [LightGBM] [Debug] Re-bagging, using 265727 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 9
# [LightGBM] [Debug] Re-bagging, using 265683 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 8
# [LightGBM] [Debug] Re-bagging, using 265618 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 10
# [LightGBM] [Debug] Re-bagging, using 264980 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 8
# [LightGBM] [Debug] Re-bagging, using 265864 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 9
# [LightGBM] [Debug] Re-bagging, using 265542 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 9
# [LightGBM] [Debug] Re-bagging, using 266017 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 9
# [LightGBM] [Debug] Re-bagging, using 265515 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 9
# [LightGBM] [Debug] Re-bagging, using 265630 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 9
# [LightGBM] [Debug] Re-bagging, using 265015 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 8
# [LightGBM] [Debug] Re-bagging, using 265269 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 8
# [LightGBM] [Debug] Re-bagging, using 265156 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 9
# [LightGBM] [Debug] Re-bagging, using 266050 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 7
# [LightGBM] [Debug] Re-bagging, using 265339 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 9
# [LightGBM] [Debug] Re-bagging, using 266115 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 9
# [LightGBM] [Debug] Re-bagging, using 265577 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 7
# [LightGBM] [Debug] Re-bagging, using 265222 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 10
# [LightGBM] [Debug] Re-bagging, using 265030 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 7
# [LightGBM] [Debug] Re-bagging, using 265690 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 8
# [LightGBM] [Debug] Re-bagging, using 265695 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 10
# [LightGBM] [Debug] Re-bagging, using 265545 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 8
# [LightGBM] [Debug] Re-bagging, using 265631 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 7
# [LightGBM] [Debug] Re-bagging, using 265234 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 8
# [LightGBM] [Debug] Re-bagging, using 265501 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 7
# [LightGBM] [Debug] Re-bagging, using 265525 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 7
# [LightGBM] [Debug] Re-bagging, using 265722 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 9
# [LightGBM] [Debug] Re-bagging, using 265301 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 8
# [LightGBM] [Debug] Re-bagging, using 265594 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 10
# [LightGBM] [Debug] Re-bagging, using 265699 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 7
# [LightGBM] [Debug] Re-bagging, using 265773 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 9
# [LightGBM] [Debug] Re-bagging, using 265570 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 9
# [LightGBM] [Debug] Re-bagging, using 265609 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 9
# [LightGBM] [Debug] Re-bagging, using 265637 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 8
# [LightGBM] [Debug] Re-bagging, using 265776 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 9
# [LightGBM] [Debug] Re-bagging, using 265387 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 8
# [LightGBM] [Debug] Re-bagging, using 265466 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 8
# [LightGBM] [Debug] Re-bagging, using 264632 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 8
# [LightGBM] [Debug] Re-bagging, using 265224 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 8
# [LightGBM] [Debug] Re-bagging, using 265522 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 7
# [LightGBM] [Debug] Re-bagging, using 265191 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 8
# [LightGBM] [Debug] Re-bagging, using 265314 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 8
# [LightGBM] [Debug] Re-bagging, using 265899 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 10
# [LightGBM] [Debug] Re-bagging, using 265080 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 8
# [LightGBM] [Debug] Re-bagging, using 265641 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 8
# [LightGBM] [Debug] Re-bagging, using 265012 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 9
# [LightGBM] [Debug] Re-bagging, using 265538 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 8
# [LightGBM] [Debug] Re-bagging, using 265383 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 8
# [LightGBM] [Debug] Re-bagging, using 265248 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 10
# [LightGBM] [Debug] Re-bagging, using 265996 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 9
# [LightGBM] [Debug] Re-bagging, using 265145 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 8
# [LightGBM] [Debug] Re-bagging, using 265326 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 8
# [LightGBM] [Debug] Re-bagging, using 265502 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 10
# [LightGBM] [Debug] Re-bagging, using 265744 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 8
# [LightGBM] [Debug] Re-bagging, using 265228 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 8
# [LightGBM] [Debug] Re-bagging, using 265338 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 9
# [LightGBM] [Debug] Re-bagging, using 265268 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 8
# [LightGBM] [Debug] Re-bagging, using 265320 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 11
# [LightGBM] [Debug] Re-bagging, using 265177 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 10
# [LightGBM] [Debug] Re-bagging, using 265208 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 8
# [LightGBM] [Debug] Re-bagging, using 265292 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 8
# [LightGBM] [Debug] Re-bagging, using 265408 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 10
# [LightGBM] [Debug] Re-bagging, using 265502 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 10
# [LightGBM] [Debug] Re-bagging, using 264983 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 8
# [LightGBM] [Debug] Re-bagging, using 265341 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 8
# [LightGBM] [Debug] Re-bagging, using 265548 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 7
# [LightGBM] [Debug] Re-bagging, using 265524 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 8
# [LightGBM] [Debug] Re-bagging, using 265578 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 8
# [LightGBM] [Debug] Re-bagging, using 265394 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 7
# [LightGBM] [Debug] Re-bagging, using 265522 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 7
# [LightGBM] [Debug] Re-bagging, using 266146 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 8
# [LightGBM] [Debug] Re-bagging, using 265311 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 10
# [LightGBM] [Debug] Re-bagging, using 265210 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 8
# [LightGBM] [Debug] Re-bagging, using 265367 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 7
# [LightGBM] [Debug] Re-bagging, using 265542 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 8
# [LightGBM] [Debug] Re-bagging, using 264947 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 11
# [LightGBM] [Debug] Re-bagging, using 265678 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 7
# [LightGBM] [Debug] Re-bagging, using 265484 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 9
# [LightGBM] [Debug] Re-bagging, using 264597 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 10
# [LightGBM] [Debug] Re-bagging, using 265707 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 7
# [LightGBM] [Debug] Re-bagging, using 265704 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 9
# [LightGBM] [Debug] Re-bagging, using 265906 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 8
# [LightGBM] [Debug] Re-bagging, using 265554 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 11
# [LightGBM] [Debug] Re-bagging, using 265938 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 8
# [LightGBM] [Debug] Re-bagging, using 265633 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 10
# [LightGBM] [Debug] Re-bagging, using 265653 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 8
# [LightGBM] [Debug] Re-bagging, using 265471 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 8
# [LightGBM] [Debug] Re-bagging, using 265121 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 8
# [LightGBM] [Debug] Re-bagging, using 265417 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 7
# [LightGBM] [Debug] Re-bagging, using 265057 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 8
# [LightGBM] [Debug] Re-bagging, using 265568 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 8
# [LightGBM] [Debug] Re-bagging, using 265646 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 8
# [LightGBM] [Debug] Re-bagging, using 265306 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 8
# [LightGBM] [Debug] Re-bagging, using 265662 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 10
# [LightGBM] [Debug] Re-bagging, using 265381 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 7
# [LightGBM] [Debug] Re-bagging, using 265462 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 8
# [LightGBM] [Debug] Re-bagging, using 265289 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 9
# [LightGBM] [Debug] Re-bagging, using 265142 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 8
# [LightGBM] [Debug] Re-bagging, using 265707 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 8
# [LightGBM] [Debug] Re-bagging, using 265377 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 8
# [LightGBM] [Debug] Re-bagging, using 265732 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 9
# [LightGBM] [Debug] Re-bagging, using 265068 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 7
# [LightGBM] [Debug] Re-bagging, using 265523 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 8
# [LightGBM] [Debug] Re-bagging, using 264996 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 10
# [LightGBM] [Debug] Re-bagging, using 265527 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 7
# [LightGBM] [Debug] Re-bagging, using 265457 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 9
# [LightGBM] [Debug] Re-bagging, using 265979 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 9
# [LightGBM] [Debug] Re-bagging, using 265486 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 8
# [LightGBM] [Debug] Re-bagging, using 265638 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 8
# [LightGBM] [Debug] Re-bagging, using 265719 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 8
# [LightGBM] [Debug] Re-bagging, using 265446 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 8
# [LightGBM] [Debug] Re-bagging, using 265588 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 8
# [LightGBM] [Debug] Re-bagging, using 265068 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 8
# [LightGBM] [Debug] Re-bagging, using 265430 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 9
# [LightGBM] [Debug] Re-bagging, using 265135 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 8
# [LightGBM] [Debug] Re-bagging, using 265792 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 8
# [LightGBM] [Debug] Re-bagging, using 265190 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 9
# [LightGBM] [Debug] Re-bagging, using 265787 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 8
# [LightGBM] [Debug] Re-bagging, using 265492 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 8
# [LightGBM] [Debug] Re-bagging, using 265648 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 11
# [LightGBM] [Debug] Re-bagging, using 265534 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 8
# [LightGBM] [Debug] Re-bagging, using 265201 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 9
# [LightGBM] [Debug] Re-bagging, using 265351 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 8
# [LightGBM] [Debug] Re-bagging, using 265191 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 9
# [LightGBM] [Debug] Re-bagging, using 265600 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 9
# [LightGBM] [Debug] Re-bagging, using 265480 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 8
# [LightGBM] [Debug] Re-bagging, using 265418 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 8
# [LightGBM] [Debug] Re-bagging, using 265640 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 7
# [LightGBM] [Debug] Re-bagging, using 265847 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 7
# [LightGBM] [Debug] Re-bagging, using 265259 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 8
# [LightGBM] [Debug] Re-bagging, using 265428 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 8
# [LightGBM] [Debug] Re-bagging, using 265352 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 8
# [LightGBM] [Debug] Re-bagging, using 265803 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 10
# [LightGBM] [Debug] Re-bagging, using 265456 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 9
# [LightGBM] [Debug] Re-bagging, using 265518 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 13
# [LightGBM] [Debug] Re-bagging, using 265354 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 8
# [LightGBM] [Debug] Re-bagging, using 265549 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 10
# [LightGBM] [Debug] Re-bagging, using 265650 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 8
# [LightGBM] [Debug] Re-bagging, using 265392 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 8
# [LightGBM] [Debug] Re-bagging, using 265319 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 9
# [LightGBM] [Debug] Re-bagging, using 265562 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 9
# [LightGBM] [Debug] Re-bagging, using 265557 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 10
# [LightGBM] [Debug] Re-bagging, using 265271 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 7
# [LightGBM] [Debug] Re-bagging, using 265427 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 11
# [LightGBM] [Debug] Re-bagging, using 265596 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 15
# [LightGBM] [Debug] Re-bagging, using 265157 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 9
# [LightGBM] [Debug] Re-bagging, using 265137 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 12
# [LightGBM] [Debug] Re-bagging, using 265436 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 7
# [LightGBM] [Debug] Re-bagging, using 265474 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 8
# [LightGBM] [Debug] Re-bagging, using 265335 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 12
# [LightGBM] [Debug] Re-bagging, using 265704 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 11
# [LightGBM] [Debug] Re-bagging, using 265611 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 11
# [LightGBM] [Debug] Re-bagging, using 265965 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 8
# [LightGBM] [Debug] Re-bagging, using 265545 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 7
# [LightGBM] [Debug] Re-bagging, using 265160 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 9
# [LightGBM] [Debug] Re-bagging, using 265642 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 10
# [LightGBM] [Debug] Re-bagging, using 265351 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 9
# [LightGBM] [Debug] Re-bagging, using 265538 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 8
# [LightGBM] [Debug] Re-bagging, using 265965 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 8
# [LightGBM] [Debug] Re-bagging, using 265347 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 10
# [LightGBM] [Debug] Re-bagging, using 265693 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 9
# [LightGBM] [Debug] Re-bagging, using 265398 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 8
# [LightGBM] [Debug] Re-bagging, using 265509 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 9
# [LightGBM] [Debug] Re-bagging, using 265813 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 9
# [LightGBM] [Debug] Re-bagging, using 265048 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 11
# [LightGBM] [Debug] Re-bagging, using 265884 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 10
# [LightGBM] [Debug] Re-bagging, using 265542 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 7
# [LightGBM] [Debug] Re-bagging, using 265160 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 11
# [LightGBM] [Debug] Re-bagging, using 265611 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 7
# [LightGBM] [Debug] Re-bagging, using 265573 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 8
# [LightGBM] [Debug] Re-bagging, using 265747 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 11
# [LightGBM] [Debug] Re-bagging, using 265484 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 9
# [LightGBM] [Debug] Re-bagging, using 265312 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 10
# [LightGBM] [Debug] Re-bagging, using 265272 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 11
# [LightGBM] [Debug] Re-bagging, using 265460 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 11
# [LightGBM] [Debug] Re-bagging, using 265858 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 8
# [LightGBM] [Debug] Re-bagging, using 265802 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 9
# [LightGBM] [Debug] Re-bagging, using 265447 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 8
# [LightGBM] [Debug] Re-bagging, using 265834 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 8
# [LightGBM] [Debug] Re-bagging, using 265801 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 9
# [LightGBM] [Debug] Re-bagging, using 265248 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 12
# [LightGBM] [Debug] Re-bagging, using 265841 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 10
# [LightGBM] [Debug] Re-bagging, using 265636 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 9
# [LightGBM] [Debug] Re-bagging, using 265990 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 9
# [LightGBM] [Debug] Re-bagging, using 265832 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 8
# [LightGBM] [Debug] Re-bagging, using 265930 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 9
# [LightGBM] [Debug] Re-bagging, using 265606 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 9
# [LightGBM] [Debug] Re-bagging, using 265726 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 10
# [LightGBM] [Debug] Re-bagging, using 265134 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 9
# [LightGBM] [Debug] Re-bagging, using 265541 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 10
# [LightGBM] [Debug] Re-bagging, using 265752 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 12
# [LightGBM] [Debug] Re-bagging, using 265098 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 10
# [LightGBM] [Debug] Re-bagging, using 265519 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 9
# [LightGBM] [Debug] Re-bagging, using 265329 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 11
# [LightGBM] [Debug] Re-bagging, using 265639 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 11
# [LightGBM] [Debug] Re-bagging, using 265516 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 10
# [LightGBM] [Debug] Re-bagging, using 265774 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 8
# [LightGBM] [Debug] Re-bagging, using 265124 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 9
# [LightGBM] [Debug] Re-bagging, using 265625 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 10
# [LightGBM] [Debug] Re-bagging, using 265301 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 11
# [LightGBM] [Debug] Re-bagging, using 265498 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 9
# [LightGBM] [Debug] Re-bagging, using 265333 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 8
# [LightGBM] [Debug] Re-bagging, using 265566 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 9
# [LightGBM] [Debug] Re-bagging, using 265312 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 8
# [LightGBM] [Debug] Re-bagging, using 265551 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 10
# [LightGBM] [Debug] Re-bagging, using 265526 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 9
# [LightGBM] [Debug] Re-bagging, using 265224 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 9
# [LightGBM] [Debug] Re-bagging, using 266050 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 10
# [LightGBM] [Debug] Re-bagging, using 265843 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 8
# [LightGBM] [Debug] Re-bagging, using 265425 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 8
# [LightGBM] [Debug] Re-bagging, using 264710 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 9
# [LightGBM] [Debug] Re-bagging, using 265744 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 12
# [LightGBM] [Debug] Re-bagging, using 265227 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 11
# [LightGBM] [Debug] Re-bagging, using 265597 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 8
# [LightGBM] [Debug] Re-bagging, using 265376 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 9
# [LightGBM] [Debug] Re-bagging, using 265493 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 9
# [LightGBM] [Debug] Re-bagging, using 265738 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 11
# [LightGBM] [Debug] Re-bagging, using 265320 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 12
# [LightGBM] [Debug] Re-bagging, using 265882 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 10
# [LightGBM] [Debug] Re-bagging, using 265998 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 11
# [LightGBM] [Debug] Re-bagging, using 265756 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 12
# [LightGBM] [Debug] Re-bagging, using 265308 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 10
# [LightGBM] [Debug] Re-bagging, using 265097 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 11
# [LightGBM] [Debug] Re-bagging, using 265748 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 14
# [LightGBM] [Debug] Re-bagging, using 265498 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 9
# [LightGBM] [Debug] Re-bagging, using 265176 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 9
# [LightGBM] [Debug] Re-bagging, using 265394 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 10
# [LightGBM] [Debug] Re-bagging, using 265276 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 9
# [LightGBM] [Debug] Re-bagging, using 265072 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 11
# [LightGBM] [Debug] Re-bagging, using 265592 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 9
# [LightGBM] [Debug] Re-bagging, using 265439 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 11
# [LightGBM] [Debug] Re-bagging, using 265399 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 10
# [LightGBM] [Debug] Re-bagging, using 265459 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 13
# [LightGBM] [Debug] Re-bagging, using 265542 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 12
# [LightGBM] [Debug] Re-bagging, using 265059 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 12
# [LightGBM] [Debug] Re-bagging, using 265414 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 9
# [LightGBM] [Debug] Re-bagging, using 265854 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 8
# [LightGBM] [Debug] Re-bagging, using 265213 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 8
# [LightGBM] [Debug] Re-bagging, using 265492 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 8
# [LightGBM] [Debug] Re-bagging, using 265384 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 9
# [LightGBM] [Debug] Re-bagging, using 265688 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 12
# [LightGBM] [Debug] Re-bagging, using 265861 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 11
# [LightGBM] [Debug] Re-bagging, using 265958 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 10
# [LightGBM] [Debug] Re-bagging, using 265748 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 9
# [LightGBM] [Debug] Re-bagging, using 265500 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 9
# [LightGBM] [Debug] Re-bagging, using 265360 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 10
# [LightGBM] [Debug] Re-bagging, using 266233 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 11
# [LightGBM] [Debug] Re-bagging, using 265263 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 8
# [LightGBM] [Debug] Re-bagging, using 265412 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 8
# [LightGBM] [Debug] Re-bagging, using 265078 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 11
# [LightGBM] [Debug] Re-bagging, using 265877 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 8
# [LightGBM] [Debug] Re-bagging, using 265503 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 9
# [LightGBM] [Debug] Re-bagging, using 265610 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 10
# [LightGBM] [Debug] Re-bagging, using 264842 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 9
# [LightGBM] [Debug] Re-bagging, using 265548 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 9
# [LightGBM] [Debug] Re-bagging, using 265738 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 13
# [LightGBM] [Debug] Re-bagging, using 265446 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 12
# [LightGBM] [Debug] Re-bagging, using 265515 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 11
# [LightGBM] [Debug] Re-bagging, using 265354 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 10
# [LightGBM] [Debug] Re-bagging, using 265979 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 11
# [LightGBM] [Debug] Re-bagging, using 265194 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 13
# [LightGBM] [Debug] Re-bagging, using 265008 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 10
# [LightGBM] [Debug] Re-bagging, using 265282 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 10
# [LightGBM] [Debug] Re-bagging, using 265469 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 13
# [LightGBM] [Debug] Re-bagging, using 265690 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 9
# [LightGBM] [Debug] Re-bagging, using 265253 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 10
# [LightGBM] [Debug] Re-bagging, using 265669 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 11
# [LightGBM] [Debug] Re-bagging, using 265739 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 7
# [LightGBM] [Debug] Re-bagging, using 265712 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 10
# [LightGBM] [Debug] Re-bagging, using 265781 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 10
# [LightGBM] [Debug] Re-bagging, using 265000 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 10
# [LightGBM] [Debug] Re-bagging, using 265412 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 10
# [LightGBM] [Debug] Re-bagging, using 265708 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 8
# [LightGBM] [Debug] Re-bagging, using 265656 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 13
# [LightGBM] [Debug] Re-bagging, using 265616 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 9
# [LightGBM] [Debug] Re-bagging, using 265944 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 12
# [LightGBM] [Debug] Re-bagging, using 265748 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 9
# [LightGBM] [Debug] Re-bagging, using 265139 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 9
# [LightGBM] [Debug] Re-bagging, using 264886 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 9
# [LightGBM] [Debug] Re-bagging, using 265530 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 9
# [LightGBM] [Debug] Re-bagging, using 265312 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 10
# [LightGBM] [Debug] Re-bagging, using 265120 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 10
# [LightGBM] [Debug] Re-bagging, using 265360 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 8
# [LightGBM] [Debug] Re-bagging, using 265218 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 11
# [LightGBM] [Debug] Re-bagging, using 265903 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 9
# [LightGBM] [Debug] Re-bagging, using 265754 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 9
# [LightGBM] [Debug] Re-bagging, using 265692 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 9
# [LightGBM] [Debug] Re-bagging, using 265351 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 9
# [LightGBM] [Debug] Re-bagging, using 265437 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 9
# [LightGBM] [Debug] Re-bagging, using 265507 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 9
# [LightGBM] [Debug] Re-bagging, using 265634 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 10
# [LightGBM] [Debug] Re-bagging, using 265527 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 11
# [LightGBM] [Debug] Re-bagging, using 265498 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 12
# [LightGBM] [Debug] Re-bagging, using 265469 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 8
# [LightGBM] [Debug] Re-bagging, using 265572 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 12
# [LightGBM] [Debug] Re-bagging, using 265664 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 9
# [LightGBM] [Debug] Re-bagging, using 265603 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 8
# [LightGBM] [Debug] Re-bagging, using 265816 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 9
# [LightGBM] [Debug] Re-bagging, using 265901 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 8
# [LightGBM] [Debug] Re-bagging, using 265663 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 11
# [LightGBM] [Debug] Re-bagging, using 265690 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 12
# [LightGBM] [Debug] Re-bagging, using 265414 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 12
# [LightGBM] [Debug] Re-bagging, using 265955 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 10
# [LightGBM] [Debug] Re-bagging, using 265258 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 10
# [LightGBM] [Debug] Re-bagging, using 265233 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 11
# [LightGBM] [Debug] Re-bagging, using 265662 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 11
# [LightGBM] [Debug] Re-bagging, using 265310 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 8
# [LightGBM] [Debug] Re-bagging, using 265851 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 9
# [LightGBM] [Debug] Re-bagging, using 265562 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 10
# [LightGBM] [Debug] Re-bagging, using 265584 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 10
# [LightGBM] [Debug] Re-bagging, using 265341 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 9
# [LightGBM] [Debug] Re-bagging, using 265960 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 9
# [LightGBM] [Debug] Re-bagging, using 265379 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 10
# [LightGBM] [Debug] Re-bagging, using 265847 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 11
# [LightGBM] [Debug] Re-bagging, using 265881 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 10
# [LightGBM] [Debug] Re-bagging, using 265324 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 14
# [LightGBM] [Debug] Re-bagging, using 265517 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 10
# [LightGBM] [Debug] Re-bagging, using 266404 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 10
# [LightGBM] [Debug] Re-bagging, using 265351 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 11
# [LightGBM] [Debug] Re-bagging, using 265110 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 13
# [LightGBM] [Debug] Re-bagging, using 265422 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 9
# [LightGBM] [Debug] Re-bagging, using 265700 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 10
# [LightGBM] [Debug] Re-bagging, using 265619 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 11
# [LightGBM] [Debug] Re-bagging, using 265177 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 9
# [LightGBM] [Debug] Re-bagging, using 265596 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 9
# [LightGBM] [Debug] Re-bagging, using 265370 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 9
# [LightGBM] [Debug] Re-bagging, using 265083 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 13
# [LightGBM] [Debug] Re-bagging, using 265667 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 11
# [LightGBM] [Debug] Re-bagging, using 265474 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 10
# [LightGBM] [Debug] Re-bagging, using 265635 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 10
# [LightGBM] [Debug] Re-bagging, using 265398 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 11
# [LightGBM] [Debug] Re-bagging, using 265739 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 9
# [LightGBM] [Debug] Re-bagging, using 265734 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 11
# [LightGBM] [Debug] Re-bagging, using 265049 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 10
# [LightGBM] [Debug] Re-bagging, using 265609 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 10
# [LightGBM] [Debug] Re-bagging, using 265306 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 12
# [LightGBM] [Debug] Re-bagging, using 265658 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 11
# [LightGBM] [Debug] Re-bagging, using 265456 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 12
# [LightGBM] [Debug] Re-bagging, using 265772 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 12
# [LightGBM] [Debug] Re-bagging, using 265163 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 13
# [LightGBM] [Debug] Re-bagging, using 265716 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 13
# [LightGBM] [Debug] Re-bagging, using 265224 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 10
# [LightGBM] [Debug] Re-bagging, using 265713 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 13
# [LightGBM] [Debug] Re-bagging, using 265114 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 9
# [LightGBM] [Debug] Re-bagging, using 265618 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 11
# [LightGBM] [Debug] Re-bagging, using 265229 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 11
# [LightGBM] [Debug] Re-bagging, using 265350 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 10
# [LightGBM] [Debug] Re-bagging, using 265413 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 11
# [LightGBM] [Debug] Re-bagging, using 265381 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 13
# [LightGBM] [Debug] Re-bagging, using 265099 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 10
# [LightGBM] [Debug] Re-bagging, using 265646 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 13
# [LightGBM] [Debug] Re-bagging, using 265489 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 11
# [LightGBM] [Debug] Re-bagging, using 265518 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 11
# [LightGBM] [Debug] Re-bagging, using 265474 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 9
# [LightGBM] [Debug] Re-bagging, using 265603 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 8
# [LightGBM] [Debug] Re-bagging, using 265260 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 10
# [LightGBM] [Debug] Re-bagging, using 265558 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 12
# [LightGBM] [Debug] Re-bagging, using 265527 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 11
# [LightGBM] [Debug] Re-bagging, using 265432 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 10
# [LightGBM] [Debug] Re-bagging, using 266162 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 12
# [LightGBM] [Debug] Re-bagging, using 265759 data to train
# ...
# [LightGBM] [Debug] Re-bagging, using 265738 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 15
# [LightGBM] [Debug] Re-bagging, using 265274 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 10
# [LightGBM] [Debug] Re-bagging, using 265353 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 10
# [LightGBM] [Debug] Re-bagging, using 265539 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 11
# [LightGBM] [Debug] Re-bagging, using 265702 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 11
# [LightGBM] [Debug] Re-bagging, using 265513 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 10
# [LightGBM] [Debug] Re-bagging, using 265564 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 8
# [LightGBM] [Debug] Re-bagging, using 265691 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 12
# [LightGBM] [Debug] Re-bagging, using 265311 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 11
# [LightGBM] [Debug] Re-bagging, using 265779 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 11
# [LightGBM] [Debug] Re-bagging, using 265455 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 10
# [LightGBM] [Debug] Re-bagging, using 265613 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 9
# [LightGBM] [Debug] Re-bagging, using 265832 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 9
# [LightGBM] [Debug] Re-bagging, using 265751 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 11
# [LightGBM] [Debug] Re-bagging, using 265197 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 9
# [LightGBM] [Debug] Re-bagging, using 265345 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 9
# [LightGBM] [Debug] Re-bagging, using 264959 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 8
# [LightGBM] [Debug] Re-bagging, using 265791 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 10
# [LightGBM] [Debug] Re-bagging, using 265808 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 9
# [LightGBM] [Debug] Re-bagging, using 265509 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 8
# [LightGBM] [Debug] Re-bagging, using 265561 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 11
# [LightGBM] [Debug] Re-bagging, using 265445 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 8
# [LightGBM] [Debug] Re-bagging, using 265745 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 12
# [LightGBM] [Debug] Re-bagging, using 265540 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 10
# [LightGBM] [Debug] Re-bagging, using 265251 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 13
# [LightGBM] [Debug] Re-bagging, using 265620 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 8
# [LightGBM] [Debug] Re-bagging, using 265586 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 11
# [LightGBM] [Debug] Re-bagging, using 265350 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 10
# [LightGBM] [Debug] Re-bagging, using 265500 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 12
# [LightGBM] [Debug] Re-bagging, using 265587 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 10
# [LightGBM] [Debug] Re-bagging, using 265386 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 10
# [LightGBM] [Debug] Re-bagging, using 265544 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 8
# [LightGBM] [Debug] Re-bagging, using 265523 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 10
# [LightGBM] [Debug] Re-bagging, using 265163 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 11
# [LightGBM] [Debug] Re-bagging, using 265361 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 10
# [LightGBM] [Debug] Re-bagging, using 265179 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 9
# [LightGBM] [Debug] Re-bagging, using 265194 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 10
# [LightGBM] [Debug] Re-bagging, using 264839 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 12
# [LightGBM] [Debug] Re-bagging, using 265604 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 10
# [LightGBM] [Debug] Re-bagging, using 265529 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 10
# [LightGBM] [Debug] Re-bagging, using 265940 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 9
# [LightGBM] [Debug] Re-bagging, using 265390 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 9
# [LightGBM] [Debug] Re-bagging, using 265066 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 11
# [LightGBM] [Debug] Re-bagging, using 265884 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 12
# [LightGBM] [Debug] Re-bagging, using 265521 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 9
# [LightGBM] [Debug] Re-bagging, using 265342 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 11
# [LightGBM] [Debug] Re-bagging, using 265717 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 9
# [LightGBM] [Debug] Re-bagging, using 265772 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 13
# [LightGBM] [Debug] Re-bagging, using 265923 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 8
# [LightGBM] [Debug] Re-bagging, using 265239 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 9
# [LightGBM] [Debug] Re-bagging, using 265159 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 13
# [LightGBM] [Debug] Re-bagging, using 265938 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 11
# [LightGBM] [Debug] Re-bagging, using 265204 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 12
# [LightGBM] [Debug] Re-bagging, using 265499 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 12
# [LightGBM] [Debug] Re-bagging, using 265227 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 10
# [LightGBM] [Debug] Re-bagging, using 265435 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 10
# [LightGBM] [Debug] Re-bagging, using 265028 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 10
# [LightGBM] [Debug] Re-bagging, using 265714 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 10
# [LightGBM] [Debug] Re-bagging, using 265244 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 12
# [LightGBM] [Debug] Re-bagging, using 265583 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 9
# [LightGBM] [Debug] Re-bagging, using 265254 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 12
# [LightGBM] [Debug] Re-bagging, using 265176 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 10
# [LightGBM] [Debug] Re-bagging, using 264974 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 11
# [LightGBM] [Debug] Re-bagging, using 265664 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 10
# [LightGBM] [Debug] Re-bagging, using 265633 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 10
# [LightGBM] [Debug] Re-bagging, using 265280 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 9
# [LightGBM] [Debug] Re-bagging, using 265491 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 12
# [LightGBM] [Debug] Re-bagging, using 264896 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 11
# [LightGBM] [Debug] Re-bagging, using 265464 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 9
# [LightGBM] [Debug] Re-bagging, using 265456 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 10
# [LightGBM] [Debug] Re-bagging, using 265717 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 8
# [LightGBM] [Debug] Re-bagging, using 265212 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 9
# [LightGBM] [Debug] Re-bagging, using 265382 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 12
# [LightGBM] [Debug] Re-bagging, using 264920 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 11
# [LightGBM] [Debug] Re-bagging, using 265778 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 16
# [LightGBM] [Debug] Re-bagging, using 265371 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 11
# [LightGBM] [Debug] Re-bagging, using 265125 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 13
# [LightGBM] [Debug] Re-bagging, using 266132 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 11
# [LightGBM] [Debug] Re-bagging, using 265163 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 13
# [LightGBM] [Debug] Re-bagging, using 265574 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 10
# [LightGBM] [Debug] Re-bagging, using 265811 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 11
# [LightGBM] [Debug] Re-bagging, using 265382 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 12
# [LightGBM] [Debug] Re-bagging, using 265234 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 11
# [LightGBM] [Debug] Re-bagging, using 265316 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 9
# [LightGBM] [Debug] Re-bagging, using 265741 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 10
# [LightGBM] [Debug] Re-bagging, using 265728 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 9
# [LightGBM] [Debug] Re-bagging, using 265297 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 12
# [LightGBM] [Debug] Re-bagging, using 265605 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 13
# [LightGBM] [Debug] Re-bagging, using 265333 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 9
# [LightGBM] [Debug] Re-bagging, using 265727 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 10
# [LightGBM] [Debug] Re-bagging, using 265448 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 14
# [LightGBM] [Debug] Re-bagging, using 265227 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 12
# [LightGBM] [Debug] Re-bagging, using 265380 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 14
# [LightGBM] [Debug] Re-bagging, using 264882 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 10
# [LightGBM] [Debug] Re-bagging, using 265408 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 11
# [LightGBM] [Debug] Re-bagging, using 265271 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 10
# [LightGBM] [Debug] Re-bagging, using 266051 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 12
# [LightGBM] [Debug] Re-bagging, using 265072 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 10
# [LightGBM] [Debug] Re-bagging, using 265013 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 11
# [LightGBM] [Debug] Re-bagging, using 265077 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 9
# [LightGBM] [Debug] Re-bagging, using 265621 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 11
# [LightGBM] [Debug] Re-bagging, using 265336 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 13
# [LightGBM] [Debug] Re-bagging, using 265433 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 11
# [LightGBM] [Debug] Re-bagging, using 265677 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 9
# [LightGBM] [Debug] Re-bagging, using 266025 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 13
# [LightGBM] [Debug] Re-bagging, using 265972 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 11
# [LightGBM] [Debug] Re-bagging, using 265126 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 10
# [LightGBM] [Debug] Re-bagging, using 265537 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 11
# [LightGBM] [Debug] Re-bagging, using 265738 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 13
# [LightGBM] [Debug] Re-bagging, using 265176 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 12
# [LightGBM] [Debug] Re-bagging, using 265433 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 9
# [LightGBM] [Debug] Re-bagging, using 265430 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 13
# [LightGBM] [Debug] Re-bagging, using 265269 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 11
# [LightGBM] [Debug] Re-bagging, using 265882 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 10
# [LightGBM] [Debug] Re-bagging, using 265197 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 11
# [LightGBM] [Debug] Re-bagging, using 265727 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 14
# [LightGBM] [Debug] Re-bagging, using 264943 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 11
# [LightGBM] [Debug] Re-bagging, using 264982 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 9
# [LightGBM] [Debug] Re-bagging, using 265428 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 9
# [LightGBM] [Debug] Re-bagging, using 264978 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 9
# [LightGBM] [Debug] Re-bagging, using 266046 data to train
# [LightGBM] [Debug] Trained a tree with leaves = 31 and max_depth = 10
# LGBMClassifier(boosting_type='gbdt', class_weight=None, colsample_bytree=0.7,
#                importance_type='split', learning_rate=0.01, max_depth=-1,
#                min_child_samples=20, min_child_weight=50, min_split_gain=0.0,
#                n_estimators=500, n_jobs=16, num_leaves=31, objective=None,
#                random_state=2018, reg_alpha=0.0, reg_lambda=1, silent=True,
#                subsample=0.7, subsample_for_bin=200000, subsample_freq=1,
#                verbose=10)

# %%
tst_user_item_feats_df['pred_score'] = lgb_Classfication.predict_proba(tst_user_item_feats_df[lgb_cols])[:,1]

# %%
tst_user_item_feats_df[tst_user_item_feats_df["user_id"]==200001]
# Out:
#          user_id  click_article_id       sim0  time_diff0  word_diff0  \
# 10233     200001            336221  10.237462   638233000          18
# 93366     200001            272143  11.962455    13058000           8
# 116844    200001            234698  10.895900   643669000           7
# 327387    200001            235616  10.165027   661541000          44
# 369092    200001            300473   5.471592    14013000           6
# ...          ...               ...        ...         ...         ...
# 2423470   200001            187067   5.292248    25713000          54
# 2437100   200001             70033   5.824065    43667000          41
# 2438515   200001            236613   4.835308    78904000           2
# 2452083   200001             50864   5.461739    48726000          26
# 2465597   200001             73500   4.480184    48527000           5
#
#            sim_max    sim_min    sim_sum   sim_mean  score  ...  click_os  \
# 10233    10.237462  10.237462  10.237462  10.237462      1  ...         2
# 93366    11.962455  11.962455  11.962455  11.962455      3  ...         2
# 116844   10.895900  10.895900  10.895900  10.895900      1  ...         2
# 327387   10.165027  10.165027  10.165027  10.165027      1  ...         2
# 369092    5.471592   5.471592   5.471592   5.471592      1  ...         2
# ...            ...        ...        ...        ...    ...  ...       ...
# 2423470   5.292248   5.292248   5.292248   5.292248      1  ...         2
# 2437100   5.824065   5.824065   5.824065   5.824065      1  ...         2
# 2438515   4.835308   4.835308   4.835308   4.835308      1  ...         2
# 2452083   5.461739   5.461739   5.461739   5.461739      1  ...         2
# 2465597   4.480184   4.480184   4.480184   4.480184      1  ...         2
#
#          click_country  click_region  click_referrer_type  words_hbo  \
# 10233                1            18                    7      176.0
# 93366                1            18                    7      176.0
# 116844               1            18                    7      176.0
# 327387               1            18                    7      176.0
# 369092               1            18                    7      176.0
# ...                ...           ...                  ...        ...
# 2423470              1            18                    7      176.0
# 2437100              1            18                    7      176.0
# 2438515              1            18                    7      176.0
# 2452083              1            18                    7      176.0
# 2465597              1            18                    7      176.0
#
#          category_id  created_at_ts  words_count  is_cat_hab  pred_score
# 10233            437  1507613161000          158           0    0.132551
# 93366            399  1506961870000          184           0    0.016482
# 116844           375  1507618597000          183           0    0.134010
# 327387           375  1507636469000          220           0    0.128850
# 369092           428  1506960915000          182           0    0.245270
# ...              ...            ...          ...         ...         ...
# 2423470          302  1506949215000          122           0    0.247401
# 2437100          136  1507018595000          217           0    0.180622
# 2438515          375  1506896024000          174           0    0.124243
# 2452083           99  1506926202000          202           0    0.196978
# 2465597          138  1506926401000          181           0    0.220423
#
# [123 rows x 26 columns]

# %%
rank_results = tst_user_item_feats_df[['user_id', 'click_article_id', 'pred_score']]
rank_results['click_article_id'] = rank_results['click_article_id'].astype(int)
submit(rank_results, topk=5, model_name='lgb_cls')
